# %% [markdown]
# <a href="https://colab.research.google.com/github/hiro106/colab_notebooks/blob/main/methods_tests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html

# %%
import pandas as pd

# %%
df = pd.DataFrame([[1, 2], [4, 5], [7, 8]],
     index=['cobra', 'viper', 'sidewinder'],
     columns=['max_speed', 'shield'])

# %%
df
# Out:
#             max_speed  shield
# cobra               1       2
# viper               4       5
# sidewinder          7       8

# %%
df.loc['viper']
# Out:
# max_speed    4
# shield       5
# Name: viper, dtype: int64

# %%
df.loc[['viper', 'sidewinder']]
# Out:
#             max_speed  shield
# viper               4       5
# sidewinder          7       8

# %%
df.loc['cobra', 'shield']
# Out:
# 2
